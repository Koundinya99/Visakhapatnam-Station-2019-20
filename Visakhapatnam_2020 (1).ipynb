# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from google.colab import files
import io
uploaded = files.upload()
# Out:
#      <input type="file" id="files-6393d9e8-9b2a-4a4c-bef1-e75d30b9a1e0" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-6393d9e8-9b2a-4a4c-bef1-e75d30b9a1e0">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Visakhapatnam_2020.csv to Visakhapatnam_2020.csv

# %%
df=pd.read_csv(io.BytesIO(uploaded['Visakhapatnam_2020.csv']))
df.head() #displays first 5 elements
# Out:
#          Station      Timestamp  ...  Unnamed: 4  Unnamed: 5
# 0  Visakhapatnam  1/1/2020 0:01  ...         0.0        32.5
# 1  Visakhapatnam  1/1/2020 0:02  ...         0.0        32.4
# 2  Visakhapatnam  1/1/2020 0:03  ...         0.0        30.9
# 3  Visakhapatnam  1/1/2020 0:04  ...         0.0        30.5
# 4  Visakhapatnam  1/1/2020 0:05  ...         0.0        31.2
#
# [5 rows x 6 columns]

# %%
df['Radar Sensor (m)']
# Out:
# 0         0.2786
# 1         0.2740
# 2         0.2593
# 3         0.2556
# 4         0.2659
#            ...
# 422371    0.5170
# 422372    0.5248
# 422373    0.5205
# 422374    0.5205
# 422375    0.5404
# Name: Radar Sensor (m), Length: 422376, dtype: float64

# %%
r_s=df['Radar Sensor (m)']
r_s
# Out:
# 0         0.2786
# 1         0.2740
# 2         0.2593
# 3         0.2556
# 4         0.2659
#            ...
# 422371    0.5170
# 422372    0.5248
# 422373    0.5205
# 422374    0.5205
# 422375    0.5404
# Name: Radar Sensor (m), Length: 422376, dtype: float64

# %%
#for 3 months--91173
date=df.iloc[:108542,1]
date
# Out:
# 0           1/1/2020 0:01
# 1           1/1/2020 0:02
# 2           1/1/2020 0:03
# 3           1/1/2020 0:04
# 4           1/1/2020 0:05
#                ...
# 108537    3/31/2020 23:54
# 108538    3/31/2020 23:55
# 108539    3/31/2020 23:56
# 108540    3/31/2020 23:58
# 108541    3/31/2020 23:59
# Name: Timestamp, Length: 108542, dtype: object

# %%
date1=df.iloc[:108542,3]
date1
# Out:
# 0         0.2786
# 1         0.2740
# 2         0.2593
# 3         0.2556
# 4         0.2659
#            ...
# 108537    0.3135
# 108538    0.3001
# 108539    0.3133
# 108540    0.3133
# 108541    0.2925
# Name: Radar Sensor (m), Length: 108542, dtype: float64

# %%
X_train=r_s[0:108542]
Y_train=r_s[1:108543]
Y_train
# Out:
# 1         0.2740
# 2         0.2593
# 3         0.2556
# 4         0.2659
# 5         0.2642
#            ...
# 108538    0.3001
# 108539    0.3133
# 108540    0.3133
# 108541    0.2925
# 108542    0.2961
# Name: Radar Sensor (m), Length: 108542, dtype: float64

# %%
X_train=np.reshape(np.array(X_train),(108542,1,1))
Y_train=np.reshape(np.array(Y_train),(108543,1,1))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-7-268a7e459c95> in <module>()
#       1 X_train=np.reshape(np.array(X_train),(108542,1,1))
# ----> 2 Y_train=np.reshape(np.array(Y_train),(108543,1,1))
#
# <__array_function__ internals> in reshape(*args, **kwargs)
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in reshape(a, newshape, order)
#     297            [5, 6]])
#     298     """
# --> 299     return _wrapfunc(a, 'reshape', newshape, order=order)
#     300
#     301
#
# /usr/local/lib/python3.7/dist-packages/numpy/core/fromnumeric.py in _wrapfunc(obj, method, *args, **kwds)
#      56
#      57     try:
# ---> 58         return bound(*args, **kwds)
#      59     except TypeError:
#      60         # A TypeError occurs if the object does have such a method in its
#
# ValueError: cannot reshape array of size 108542 into shape (108543,1,1)

# %%
from keras.layers import Dense,LSTM
from keras.models import Sequential

# %%
reg=Sequential()
reg.add(LSTM(units=4,activation='relu',input_shape=(None,1)))
reg.add(Dense(units=1))
reg.compile(optimizer='adam',loss='mean_squared_error')
reg.fit(X_train,Y_train,batch_size=10,epochs=25)
# Out:
# WARNING:tensorflow:Layer lstm will not use cuDNN kernels since it doesn't meet the criteria. It will use a generic GPU kernel as fallback when running on GPU.
# Epoch 1/25
# 10855/10855 [==============================] - 71s 4ms/step - loss: 0.0345
# Epoch 2/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2220e-04
# Epoch 3/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2570e-04
# Epoch 4/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2627e-04
# Epoch 5/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2624e-04
# Epoch 6/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2779e-04
# Epoch 7/25
# 10855/10855 [==============================] - 47s 4ms/step - loss: 1.1992e-04
# Epoch 8/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2212e-04
# Epoch 9/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.1996e-04
# Epoch 10/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2112e-04
# Epoch 11/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2245e-04
# Epoch 12/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2293e-04
# Epoch 13/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2039e-04
# Epoch 14/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2534e-04
# Epoch 15/25
# 10855/10855 [==============================] - 47s 4ms/step - loss: 1.1993e-04
# Epoch 16/25
# 10855/10855 [==============================] - 47s 4ms/step - loss: 1.1918e-04
# Epoch 17/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.2446e-04
# Epoch 18/25
# 10855/10855 [==============================] - 47s 4ms/step - loss: 1.1833e-04
# Epoch 19/25
# 10855/10855 [==============================] - 47s 4ms/step - loss: 1.2265e-04
# Epoch 20/25
# 10855/10855 [==============================] - 47s 4ms/step - loss: 1.2276e-04
# Epoch 21/25
# 10855/10855 [==============================] - 47s 4ms/step - loss: 1.2219e-04
# Epoch 22/25
# 10855/10855 [==============================] - 47s 4ms/step - loss: 1.2296e-04
# Epoch 23/25
# 10855/10855 [==============================] - 47s 4ms/step - loss: 1.2089e-04
# Epoch 24/25
# 10855/10855 [==============================] - 48s 4ms/step - loss: 1.1837e-04
# Epoch 25/25
# 10855/10855 [==============================] - 49s 4ms/step - loss: 1.2143e-04

# %%
uploaded1 = files.upload()
dg=pd.read_csv(io.BytesIO(uploaded['Visakhapatnam_2020.csv']))
# Out:
#      <input type="file" id="files-67aa6d0a-dd99-4bb0-829e-a02018aa15e2" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-67aa6d0a-dd99-4bb0-829e-a02018aa15e2">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Visakhapatnam_2020.csv to Visakhapatnam_2020 (1).csv

# %%
#test with 4 month
dg.iloc[108542:142642,3]
# Out:
# 108542    0.2961
# 108543    0.2961
# 108544    0.2978
# 108545    0.2876
# 108546    0.2876
#            ...
# 142637    0.5496
# 142638    0.5485
# 142639    0.5438
# 142640    0.5449
# 142641    0.5535
# Name: Radar Sensor (m), Length: 34100, dtype: float64

# %%
dg1=dg.iloc[108542:142642,3].values
dg1=np.reshape(dg1,(34100,1,1))
dg1
# Out:
# array([[[0.2961]],
#
#        [[0.2961]],
#
#        [[0.2978]],
#
#        ...,
#
#        [[0.5438]],
#
#        [[0.5449]],
#
#        [[0.5535]]])

# %%
reg.predict(dg1)
# Out:
# array([[0.29638132],
#        [0.29638132],
#        [0.29808357],
#        ...,
#        [0.544316  ],
#        [0.54541487],
#        [0.5540074 ]], dtype=float32)

# %%
dg2=dg.iloc[108542:142642,3].values

# %%
plt.figure(figsize=(12,5))
plt.plot(np.arange(0,34100),dg2,label='Observed')
plt.plot(np.arange(0,34100),reg.predict(dg1),label='Predicted',linestyle='dotted')
plt.xlabel('Date')
plt.ylabel('Height (m)')
plt.title('ML Predicted vs Observed height')
plt.legend()

# %%
from sklearn.metrics import mean_squared_error
print('RMSE: ',np.sqrt(mean_squared_error(dg2,reg.predict(dg1))))
# Out:
# RMSE:  0.000963140342224913

# %%
dg_all=dg['Radar Sensor (m)'].values
dg_all=np.reshape(dg_all,(422376,1,1))
dg_all
# Out:
# array([[[0.2786]],
#
#        [[0.274 ]],
#
#        [[0.2593]],
#
#        ...,
#
#        [[0.5205]],
#
#        [[0.5205]],
#
#        [[0.5404]]])

# %%
reg.predict(dg_all)
# Out:
# array([[0.27886304],
#        [0.27425957],
#        [0.25955245],
#        ...,
#        [0.52104425],
#        [0.52104425],
#        [0.5409195 ]], dtype=float32)

# %%
plt.figure(figsize=(12,5))
z=np.linspace(-81,35)
plt.plot(z,z,label='Reference Line (Straight line for comparison')
plt.plot(dg['Radar Sensor (m)'].values,reg.predict(dg_all),label='ML model',color='black',linestyle='dotted')
plt.xlabel('Actual Height (m)')
plt.ylabel('Predicted Height (m)')
plt.legend()
plt.grid()

# %%
dg['Radar Sensor (m)'].min()
# Out:
# -81.2642
